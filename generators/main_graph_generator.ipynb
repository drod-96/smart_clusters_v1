# %% [markdown]
# ### Generate random graph from scratch

# %%
from graph_generator import GraphDHNGenerator, GraphGeneratorParameters

params = GraphGeneratorParameters(target_ratio=1.001, nb_regions=2, nb_nodes_per_region=70, E_rp=0.1, E_ee=0.1, max_degree=3, edge_weight_mean=1.0, edge_weight_std=0.01)
generator = GraphDHNGenerator(params)

# %%
generator.generate_random_connected_dhn()
print(f'Producers are = {generator.producer_indices}')
# Out:
# Generating each region ...
# 	Region 1
# 	Region 2
# Loop --> adding edges between regions
# 	 --> finished
# Close producers =  []
# Diameter =  41
# Ratio (E/V) total = 1.0431654676258992
# Short cycles found:
# [(72, 74), (74, 97), (97, 72)]
# Graph generation done !!
# Producers are = [21]
